# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=np.linspace(0,5,50)
y=1.2*x+0.8+0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=20)
x_train
# Out:
# array([4.08163265, 1.73469388, 1.83673469, 0.        , 2.75510204,
#        3.36734694, 3.67346939, 4.28571429, 1.02040816, 0.30612245,
#        4.18367347, 1.32653061, 4.69387755, 0.20408163, 3.87755102,
#        3.97959184, 0.51020408, 4.3877551 , 3.7755102 , 3.06122449,
#        0.6122449 , 2.95918367, 1.63265306, 1.93877551, 5.        ,
#        4.48979592, 2.14285714, 3.26530612, 3.46938776, 0.71428571,
#        2.24489796, 1.12244898, 2.04081633, 0.91836735, 4.89795918,
#        2.85714286, 3.16326531, 1.53061224, 2.65306122, 3.57142857])

# %%
y
# Out:
# array([2.17052254, 1.33942216, 1.2225679 , 1.94515071, 1.70627685,
#        1.20363893, 1.01355371, 2.61734969, 0.68297794, 2.93676435,
#        1.94113836, 2.63305724, 2.71267626, 2.14418097, 2.08726615,
#        3.6255427 , 3.38305356, 3.28967852, 3.08521323, 3.1884232 ,
#        2.81552216, 2.42331254, 3.77794873, 3.14208535, 4.53130752,
#        3.81554288, 4.63643281, 4.56229147, 4.64518162, 4.15189652,
#        4.72317547, 4.00426542, 4.93988796, 4.40814146, 3.93482554,
#        5.26378606, 5.05244201, 5.5922029 , 4.41577742, 6.55923974,
#        5.5298972 , 6.44729744, 5.03289984, 7.57424016, 5.97840505,
#        5.24350244, 6.85410654, 6.70470836, 6.37997439, 5.56909497])

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,y_test,c='r')

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr=LinearRegression()
X_train=x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.12837191]
# interception:  0.9527652605111325

# %%
Y_train=regr.predict(X_train)

# %%
mse=sum((Y_train-y_train)**2)/len(Y_train)
mse
# Out:
# 0.32543809894126785

# %%
plt.scatter(x_train,y_train)
plt.plot(X_train,Y_train)

# %% [markdown]
# #### test with test data

# %%
X_test=x_test.reshape(-1,1)
Y_test=regr.predict(X_test)
Y_test
# Out:
# array([2.33444515, 2.56472513, 1.41332522, 1.87388518, 6.13406484,
#        1.06790525, 3.83126502, 3.71612503, 6.36434482, 3.60098504])

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
w=regr.coef_
b=regr.intercept_
Y_test=w*X_test+b
Y_test
# Out:
# array([[2.33444515],
#        [2.56472513],
#        [1.41332522],
#        [1.87388518],
#        [6.13406484],
#        [1.06790525],
#        [3.83126502],
#        [3.71612503],
#        [6.36434482],
#        [3.60098504]])

# %%
mse=np.sum((Y_test-y_test)**2)/len(Y_test)
mse
# Out:
# 0.6146985061180756

# %%
plt.scatter(x_test,y_test,label='ground truth')
plt.scatter(x_test,Y_test,c='r',label='predict')
title=f'f(x)=1.2x+0.8, mse={round(mse,2)}'
plt.title(title)
plt.legend()
